# %% [markdown]
# Read the three files into python as dataframes

# %%
import pandas as pd
import numpy as np

# %%
file1 = pd.read_csv('C:/Users/mahna/Ironhack/Week1/Day2/Morning/lab-customer-analysis-round-1/files_for_lab/csv_files/file1.csv')

# %%
file2 = pd.read_csv('C:/Users/mahna/Ironhack/Week1/Day2/Morning/lab-customer-analysis-round-1/files_for_lab/csv_files/file2.csv')

# %%
file3 = pd.read_csv('C:/Users/mahna/Ironhack/Week1/Day2/Morning/lab-customer-analysis-round-1/files_for_lab/csv_files/file3.csv')

# %% [markdown]
# Show the DataFrame's shape.

# %%
display(file1.head())
file1.shape
# Out:
#   Customer          ST GENDER             Education Customer Lifetime Value  \
# 0  RB50392  Washington    NaN                Master                     NaN
# 1  QZ44356     Arizona      F              Bachelor              697953.59%
# 2  AI49188      Nevada      F              Bachelor             1288743.17%
# 3  WW63253  California      M              Bachelor              764586.18%
# 4  GA49547  Washington      M  High School or Below              536307.65%
#
#     Income  Monthly Premium Auto Number of Open Complaints     Policy Type  \
# 0      0.0                1000.0                    1/0/00   Personal Auto
# 1      0.0                  94.0                    1/0/00   Personal Auto
# 2  48767.0                 108.0                    1/0/00   Personal Auto
# 3      0.0                 106.0                    1/0/00  Corporate Auto
# 4  36357.0                  68.0                    1/0/00   Personal Auto
#
#    Vehicle Class  Total Claim Amount
# ...

# %%
display(file2.head())
display(file2.tail())
file2.shape
# Out:
#   Customer          ST GENDER Education Customer Lifetime Value  Income  \
# 0  GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1  CW49887  California      F    Master              462680.11%   79487
# 2  MY31220  California      F   College              899704.02%   54230
# 3  UH35128      Oregon      F   College             2580706.30%   71210
# 4  WH52799     Arizona      F   College              380812.21%   94903
#
#    Monthly Premium Auto Number of Open Complaints  Total Claim Amount  \
# 0                    88                    1/0/00               633.6
# 1                   114                    1/0/00               547.2
# 2                   112                    1/0/00               537.6
# 3                   214                    1/1/00              1027.2
# 4                    94                    1/0/00               451.2
#
#       Policy Type  Vehicle Class
# 0   Personal Auto  Four-Door Car
# 1    Special Auto            SUV
# ...

# %%
file3.shape
# Out:
# (7070, 11)

# %%
display(file3.head())
# Out:
#   Customer       State  Customer Lifetime Value             Education Gender  \
# 0  SA25987  Washington              3479.137523  High School or Below      M
# 1  TB86706     Arizona              2502.637401                Master      M
# 2  ZL73902      Nevada              3265.156348              Bachelor      F
# 3  KX23516  California              4455.843406  High School or Below      F
# 4  FN77294  California              7704.958480  High School or Below      M
#
#    Income  Monthly Premium Auto  Number of Open Complaints    Policy Type  \
# 0       0                   104                          0  Personal Auto
# 1       0                    66                          0  Personal Auto
# 2   25820                    82                          0  Personal Auto
# 3       0                   121                          0  Personal Auto
# 4   30366                   101                          2  Personal Auto
#
#    Total Claim Amount  Vehicle Class
# ...

# %% [markdown]
# Standardize header names.

# %%
file1.columns = file1.columns.str.lower()

# %%
display(file1.head())
file1.shape
# Out:
#   customer          st gender             education customer lifetime value  \
# 0  RB50392  Washington    NaN                Master                     NaN
# 1  QZ44356     Arizona      F              Bachelor              697953.59%
# 2  AI49188      Nevada      F              Bachelor             1288743.17%
# 3  WW63253  California      M              Bachelor              764586.18%
# 4  GA49547  Washington      M  High School or Below              536307.65%
#
#     income  monthly premium auto number of open complaints     policy type  \
# 0      0.0                1000.0                    1/0/00   Personal Auto
# 1      0.0                  94.0                    1/0/00   Personal Auto
# 2  48767.0                 108.0                    1/0/00   Personal Auto
# 3      0.0                 106.0                    1/0/00  Corporate Auto
# 4  36357.0                  68.0                    1/0/00   Personal Auto
#
#    vehicle class  total claim amount
# ...

# %%
display(file1.head(1))
# Out:
#   customer          st gender education customer lifetime value  income  \
# 0  RB50392  Washington    NaN    Master                     NaN     0.0
#
#    monthly premium auto number of open complaints    policy type  \
# 0                1000.0                    1/0/00  Personal Auto
#
#    vehicle class  total claim amount
# 0  Four-Door Car            2.704934

# %%
file2.columns = file2.columns.str.lower()
display(file2.head(1))
file2.shape
# Out:
#   customer       st gender education customer lifetime value  income  \
# 0  GS98873  Arizona      F  Bachelor              323912.47%   16061
#
#    monthly premium auto number of open complaints  total claim amount  \
# 0                    88                    1/0/00               633.6
#
#      policy type  vehicle class
# 0  Personal Auto  Four-Door Car
# (996, 11)

# %%
file3.columns = file3.columns.str.lower()
display(file3.head(1))
file3.shape
# Out:
#   customer       state  customer lifetime value             education gender  \
# 0  SA25987  Washington              3479.137523  High School or Below      M
#
#    income  monthly premium auto  number of open complaints    policy type  \
# 0       0                   104                          0  Personal Auto
#
#    total claim amount vehicle class
# 0               499.2  Two-Door Car
# (7070, 11)

# %%
file3 = file3.rename(columns={'state':'st'})
file3.head()
# Out:
#   customer          st  customer lifetime value             education gender  \
# 0  SA25987  Washington              3479.137523  High School or Below      M
# 1  TB86706     Arizona              2502.637401                Master      M
# 2  ZL73902      Nevada              3265.156348              Bachelor      F
# 3  KX23516  California              4455.843406  High School or Below      F
# 4  FN77294  California              7704.958480  High School or Below      M
#
#    income  monthly premium auto  number of open complaints    policy type  \
# 0       0                   104                          0  Personal Auto
# 1       0                    66                          0  Personal Auto
# 2   25820                    82                          0  Personal Auto
# 3       0                   121                          0  Personal Auto
# 4   30366                   101                          2  Personal Auto
#
#    total claim amount  vehicle class
# ...

# %%
col1_names=file1.columns
col1_names
# Out:
# Index(['customer', 'st', 'gender', 'education', 'customer lifetime value',
#        'income', 'monthly premium auto', 'number of open complaints',
#        'policy type', 'vehicle class', 'total claim amount'],
#       dtype='object')

# %%
col2_names=file2.columns
col2_names
# Out:
# Index(['customer', 'st', 'gender', 'education', 'customer lifetime value',
#        'income', 'monthly premium auto', 'number of open complaints',
#        'total claim amount', 'policy type', 'vehicle class'],
#       dtype='object')

# %%
col3_names=file3.columns
col3_names
# Out:
# Index(['customer', 'st', 'customer lifetime value', 'education', 'gender',
#        'income', 'monthly premium auto', 'number of open complaints',
#        'policy type', 'total claim amount', 'vehicle class'],
#       dtype='object')

# %% [markdown]
# Rearrange the columns in the dataframe as needed

# %%
df2 = file2.reindex(['customer', 'st', 'gender', 'education', 'customer lifetime value',
       'income', 'monthly premium auto', 'number of open complaints',
       'policy type', 'vehicle class', 'total claim amount'], axis=1)
display(df2.head())
# Out:
#   customer          st gender education customer lifetime value  income  \
# 0  GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1  CW49887  California      F    Master              462680.11%   79487
# 2  MY31220  California      F   College              899704.02%   54230
# 3  UH35128      Oregon      F   College             2580706.30%   71210
# 4  WH52799     Arizona      F   College              380812.21%   94903
#
#    monthly premium auto number of open complaints     policy type  \
# 0                    88                    1/0/00   Personal Auto
# 1                   114                    1/0/00    Special Auto
# 2                   112                    1/0/00   Personal Auto
# 3                   214                    1/1/00   Personal Auto
# 4                    94                    1/0/00  Corporate Auto
#
#    vehicle class  total claim amount
# 0  Four-Door Car               633.6
# 1            SUV               547.2
# ...

# %%
df3 = file3.reindex(['customer', 'st', 'gender', 'education', 'customer lifetime value',
       'income', 'monthly premium auto', 'number of open complaints',
       'policy type', 'vehicle class', 'total claim amount'], axis=1)
display(df3.head())
# Out:
#   customer          st gender             education  customer lifetime value  \
# 0  SA25987  Washington      M  High School or Below              3479.137523
# 1  TB86706     Arizona      M                Master              2502.637401
# 2  ZL73902      Nevada      F              Bachelor              3265.156348
# 3  KX23516  California      F  High School or Below              4455.843406
# 4  FN77294  California      M  High School or Below              7704.958480
#
#    income  monthly premium auto  number of open complaints    policy type  \
# 0       0                   104                          0  Personal Auto
# 1       0                    66                          0  Personal Auto
# 2   25820                    82                          0  Personal Auto
# 3       0                   121                          0  Personal Auto
# 4   30366                   101                          2  Personal Auto
#
#    vehicle class  total claim amount
# ...

# %% [markdown]
# Concatenate the three dataframes

# %%
data = pd.concat([file1, file2, file3], axis=0) 
data.shape
data
# Out:
#      customer          st gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065  LA72316  California      M              Bachelor
# 7066  PK87824  California      F               College
# 7067  TD14365  California      M              Bachelor
# 7068  UP19263  California      M               College
# 7069  Y167826  California      M               College
#
#      customer lifetime value   income  monthly premium auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %% [markdown]
# Which columns are numerical?

# %%
data.select_dtypes('number').columns
# Out:
# Index(['income', 'monthly premium auto', 'total claim amount'], dtype='object')

# %% [markdown]
# Which columns are categorical?

# %%
data.select_dtypes('object').columns
# Out:
# Index(['customer', 'st', 'gender', 'education', 'customer lifetime value',
#        'number of open complaints', 'policy type', 'vehicle class'],
#       dtype='object')

# %% [markdown]
# Understand the meaning of all columns

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12074 entries, 0 to 7069
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   customer                   9137 non-null   object
#  1   st                         9137 non-null   object
#  2   gender                     9015 non-null   object
#  3   education                  9137 non-null   object
#  4   customer lifetime value    9130 non-null   object
#  5   income                     9137 non-null   float64
#  6   monthly premium auto       9137 non-null   float64
#  7   number of open complaints  9137 non-null   object
#  8   policy type                9137 non-null   object
#  9   vehicle class              9137 non-null   object
#  10  total claim amount         9137 non-null   float64
# dtypes: float64(3), object(8)
# memory usage: 1.1+ MB

# %%
data.describe()
# Out:
#              income  monthly premium auto  total claim amount
# count   9137.000000           9137.000000         9137.000000
# mean   37828.820291            110.391266          430.527140
# std    30358.716159            581.376032          289.582968
# min        0.000000             61.000000            0.099007
# 25%        0.000000             68.000000          266.996814
# 50%    34244.000000             83.000000          377.561463
# 75%    62447.000000            109.000000          546.420009
# max    99981.000000          35354.000000         2893.239678

# %% [markdown]
# Perform the data cleaning operations mentioned so far in class
#
# -Delete the column education and the number of open complaints from the dataframe.

# %%
df=data.copy()

# %%
df.drop(['education'], inplace=True, axis=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [2], in <cell line: 1>()
# ----> 1 df.drop(['education'], inplace=True, axis=1)
#
# NameError: name 'df' is not defined

# %%
display(df.head())
# Out:
#   customer          st gender customer lifetime value   income  \
# 0  RB50392  Washington    NaN                     NaN      0.0
# 1  QZ44356     Arizona      F              697953.59%      0.0
# 2  AI49188      Nevada      F             1288743.17%  48767.0
# 3  WW63253  California      M              764586.18%      0.0
# 4  GA49547  Washington      M              536307.65%  36357.0
#
#    monthly premium auto number of open complaints     policy type  \
# 0                1000.0                    1/0/00   Personal Auto
# 1                  94.0                    1/0/00   Personal Auto
# 2                 108.0                    1/0/00   Personal Auto
# 3                 106.0                    1/0/00  Corporate Auto
# 4                  68.0                    1/0/00   Personal Auto
#
#    vehicle class  total claim amount
# 0  Four-Door Car            2.704934
# 1  Four-Door Car         1131.464935
# 2   Two-Door Car          566.472247
# ...

# %%
df.drop('number of open complaints', inplace=True, axis=1)

# %%
display(df.head())
# Out:
#   customer          st gender customer lifetime value   income  \
# 0  RB50392  Washington    NaN                     NaN      0.0
# 1  QZ44356     Arizona      F              697953.59%      0.0
# 2  AI49188      Nevada      F             1288743.17%  48767.0
# 3  WW63253  California      M              764586.18%      0.0
# 4  GA49547  Washington      M              536307.65%  36357.0
#
#    monthly premium auto     policy type  vehicle class  total claim amount
# 0                1000.0   Personal Auto  Four-Door Car            2.704934
# 1                  94.0   Personal Auto  Four-Door Car         1131.464935
# 2                 108.0   Personal Auto   Two-Door Car          566.472247
# 3                 106.0  Corporate Auto            SUV          529.881344
# 4                  68.0   Personal Auto  Four-Door Car           17.269323

# %% [markdown]
# -Correct the values in the column customer lifetime value. They are given as a percent, so multiply them by 100 and change -dtype to numerical type.

# %%
customer_lifetime_value=df[['customer lifetime value']]

# %%
print(df.dtypes)
display(df)
# Out:
# customer                    object
# st                          object
# gender                      object
# customer lifetime value     object
# income                     float64
# monthly premium auto       float64
# policy type                 object
# vehicle class               object
# total claim amount         float64
# dtype: object
#      customer          st gender customer lifetime value   income  \
# 0     RB50392  Washington    NaN                     NaN      0.0
# 1     QZ44356     Arizona      F              697953.59%      0.0
# 2     AI49188      Nevada      F             1288743.17%  48767.0
# 3     WW63253  California      M              764586.18%      0.0
# 4     GA49547  Washington      M              536307.65%  36357.0
# ...       ...         ...    ...                     ...      ...
# 7065  LA72316  California      M             23405.98798  71941.0
# 7066  PK87824  California      F             3096.511217  21604.0
# ...

# %%
df.isna().sum()
# Out:
# customer                   2937
# st                         2937
# gender                     3059
# customer lifetime value    2944
# income                     2937
# monthly premium auto       2937
# policy type                2937
# vehicle class              2937
# total claim amount         2937
# dtype: int64

# %%
df['customer lifetime value'].isna().sum()
# Out:
# 2944

# %%
df['customer lifetime value'].unique()
# Out:
# array([nan, '697953.59%', '1288743.17%', ..., 8163.890428, 7524.442436,
#        2611.836866], dtype=object)

# %%
customer_lifetime_value=customer_lifetime_value.replace('%', '')
print(customer_lifetime_value)
# Out:
#      customer lifetime value
# 0                        NaN
# 1                 697953.59%
# 2                1288743.17%
# 3                 764586.18%
# 4                 536307.65%
# ...                      ...
# 7065             23405.98798
# 7066             3096.511217
# 7067             8163.890428
# 7068             7524.442436
# 7069             2611.836866
#
# [12074 rows x 1 columns]

# %%
pd.to_numeric('customer_lifetime_value')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\_libs\lib.pyx:2315, in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "customer_lifetime_value"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Input In [81], in <cell line: 1>()
# ----> 1 pd.to_numeric('customer_lifetime_value')
#
# File ~\anaconda3\lib\site-packages\pandas\core\tools\numeric.py:184, in to_numeric(arg, errors, downcast)
#     182 coerce_numeric = errors not in ("ignore", "raise")
#     183 try:
# --> 184     values, _ = lib.maybe_convert_numeric(
#     185         values, set(), coerce_numeric=coerce_numeric
#     186     )
#     187 except (ValueError, TypeError):
#     188     if errors == "raise":
#
# ...

# %% [markdown]
# -Check for duplicate rows in the data and remove if any.

# %%
df=df.drop_duplicates()

# %%
df.shape
# Out:
# (9135, 9)

# %% [markdown]
# -Filter out the data for customers who have an income of 0 or less.

# %%
df['no_income'] = df['income']<0
df.head()
df.shape
# Out:
# C:\Users\mahna\AppData\Local\Temp\ipykernel_9812\528568398.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['no_income'] = df['income']<0
# (9135, 10)
